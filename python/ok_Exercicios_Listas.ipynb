# %% [markdown]
# #### Exercício 1 - Imprima a lista de nomes recebida em ordem alfabética crescente

# %% [markdown]
# Lista de nomes: Rafaela, Patrícia, Matheus, Arnobio, Pedro, Jéssica.

# %%
lista_nomes = ['Rafaela', 'Pedro', 'Patrícia', 'Matheus', 'Jéssica', 'Arnobio']
#ordem alfabetica

lista= sorted(lista_nomes)
print(lista)
# Out:
# ['Arnobio', 'Jéssica', 'Matheus', 'Patrícia', 'Pedro', 'Rafaela']

# %% [markdown]
# #### Exercício 2 - Imprima a lista de nomes recebida em ordem alfabética decrescente

# %%
lista_nomes = ['Rafaela', 'Pedro', 'Patrícia', 'Matheus', 'Jéssica', 'Arnobio']
#ordem descrescente
lista_reverse= sorted(lista_nomes, reverse=True)
print(lista_reverse)
# Out:
# ['Rafaela', 'Pedro', 'Patrícia', 'Matheus', 'Jéssica', 'Arnobio']

# %% [markdown]
# ##### Exercício 3 - Imprima o segundo elemento da lista recebida

# %%
lista_nomes = ['Rafaela', 'Pedro', 'Patrícia', 'Matheus', 'Jéssica', 'Arnobio']
#segundo elemento
segundo = lista_nomes[1]
print(segundo)
# Out:
# Pedro

# %% [markdown]
# ##### Exercício 4 - Imprima o último elemento da lista recebida

# %%
lista_elemetos = ['Rafaela', 'Pedro', 'Patrícia', 'Matheus', 'Jéssica', 'Arnobio']
#ultimo elemento
ultimo = lista_elemetos[-1]
print(ultimo)
# Out:
# Arnobio

# %% [markdown]
# ##### Exercício 5 -  Encontrar o erro no código abaixo
# Obs: A lista não pode ser modificada

# %%
my_list = [1, 2, 3, 4, 5]
#print(my_list[5])
# a lista começa na posição zero, logo correção
print(my_list[4])
# Out:
# 5

# %% [markdown]
# ##### Exercício 6 - Encontrar o erro no código abaixo
# obs.:my_list não deverá ser modificada
#
# Último elemento da lista deverá ser removido

# %%
my_list = [1, 2, 3, 4, 5]
my_list.remove(6) # não existe esse número na lista
print(my_list[0])

# %% [markdown]
# ##### Exercício 8  -  Programa Python para trocar os primeiros e últimos elementos em uma lista

# %% [markdown]
# Dada uma lista, escreva um programa Python para trocar o primeiro e o último elemento da lista.

# %% [markdown]
# Exemplos:
# ```
# Input : [12, 35, 9, 56, 24],
# Output : [24, 35, 9, 56, 12],
#
# Input : [1, 2, 3],
# Output : [3, 2, 1]
# ```

# %%
lista = [12, 35, 9, 56, 24]

# %%
temp = lista[0]
temp
# Out:
# 12

# %%
lista[-1]
# Out:
# 24

# %%
tamanho = len(lista)

# %%
tamanho
# Out:
# 5

# %%
lista[0] = lista[tamanho - 1]

# %%
lista[tamanho - 1] = temp

# %%
lista
# Out:
# [24, 35, 9, 56, 12]
