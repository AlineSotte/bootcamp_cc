# %% [markdown]
# <div>
# <p ><img  align="right" src="https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco,dpr_1/aj29iemt0ogdyrdlksd4" height="160px"></p>
# </div>
#
# <br>
# <br>
#
# # **Exercícios Aula 02 - Entrada e Saída de Dados**
#
# <br>
# <br>
#
# ___

# %% [markdown]
# *Exercício 1: Usando o comando print*
#
# Imprima a frase "Olá, mundo!" na tela.

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# *Exercício 2: Usando f-string para Formatção*
#
# Crie um programa que solicite ao usuário seu nome e, em seguida, imprima uma mensagem de saudação com seu nome usando uma f-string.

# %%
input_name = input("Digite seu nome: ")
print (f"seu nome é {input_name}")
# Out:
# seu nome é Aline

# %% [markdown]
# *Exercício 3: Usando format() para Formatção*
#
# Crie um programa que solicite ao usuário seu nome e idade. Em seguida, imprima uma mensagem de boas-vindas com esses dados usando a função format()

# %%
input_name = input("Digite seu nome: ")
input_idade = input("Digite sua idade: ")
print("Olá, meu nome é {nome} e tenho {idade} anos.".format(nome=input_name, idade=input_idade))
# Out:
# Olá, meu nome é Aline e tenho 40 anos.
