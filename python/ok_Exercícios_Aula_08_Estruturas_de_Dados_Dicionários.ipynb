# %% [markdown]
# <div>
# <p ><img  align="right" src="https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco,dpr_1/aj29iemt0ogdyrdlksd4" height="160px"></p>
# </div>
#
# <br>
# <br>
#
# # **Aula 08 - Estruturas de Dados - Dicionários**
#
# <br>
# <br>
#
# ___
#
#
# Um dicionário é um tipo de estrutura de dados do tipo coleção, ou seja, um objeto que contém mais de um valor.
#
# Diferentemente das listas e tuplas em que os elementos são acessados através de uma posição ou índice, nos dicionários o acesso às informações ocorrem através de chaves. Além disso, os elementos de um dicionário são armazenados de forma não ordenada.
#
# **Métodos dos Dicionários**
# * **get(key[,default])**: Retorna o valor da chave se a chave estiver no dicionário, senão default.
# * **keys()**: Retorna as chaves do dicionário.
# * **values()**: Retorna os valores do dicionário.
# * **items()**: Retorna uma nova visão dos itens do dicionário (pares).
# * **pop(key[,default])**: Se a chave estiver no dicionário, remova-a e retorne seu valor, senão retorne default.
# * **popitem()**: Remove o último elemento do dicionário.
# * **clear()**: Remova todos os itens do dicionário.
# * **update()**: Atualize o dicionário com os pares chave/valor.

# %% [markdown]
# *Exercício 1: Criação e Acesso a Dicionários*
#
# Crie um dicionário chamado aluno com as seguintes informações:
# "nome": "Maria"
# "idade": 20
# "curso": "Engenharia"
# Acesse e imprima o nome do aluno.

# %%
dic = {
"nome": "Maria",
"idade": 20,
"curso": "Engenharia"
}

for i,j in dic.items():
    if i=='nome':
        print(j)

# %% [markdown]
# *Exercício 2: Acesso a Valores de Dicionário Aninhado*
#
# Crie um dicionário chamado pessoa com informações aninhadas:
# "nome": "João"
# "endereço": {"rua": "Rua A", "cidade": "Cidade X"}
# Acesse e imprima a cidade onde a pessoa mora.

# %%
pessoa = {
    "nome": "João",
    "endereço": {
        "rua": "Rua A",
        "cidade": "Cidade X"
    }
}

print(pessoa["endereço"]["cidade"])

# %% [markdown]
# *Exercício 3: Dicionário de Notas*
#
# Crie um dicionário que represente as notas de um aluno nas disciplinas "Matemática", "Inglês" e "História". Utilize os nomes das disciplinas como chaves e as notas como valores.
# Acesse e imprima a nota do aluno em "Inglês".

# %%
notas = {
    "Matemática": 8.5,
    "Inglês": 7.0,
    "História": 9.0
}

print("Nota em Inglês:", notas["Inglês"])

# %% [markdown]
# *Exercício 4: Dicionário de Produtos*
#
# Crie um dicionário que represente informações de um produto, incluindo nome, preço e quantidade em estoque.
# Acesse e imprima o preço do produto.
# python

# %%
produto = {
    "nome": "Caneta",
    "preço": 2.50,
    "quantidade": 100
}

print("Preço do produto:", produto["preço"])
